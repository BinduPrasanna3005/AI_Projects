# %%
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import VGG16
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import classification_report

# Define paths
train_path = 'C:/Users/phd/Downloads/datasets (2)/datasets/balance_dataset/train'
test_path = 'C:/Users/phd/Downloads/datasets (2)/datasets/balance_dataset/test'

# Image parameters
img_height, img_width = 150, 150
batch_size = 32
num_classes = 1  # binary classification

# Prepare the dataset
train_datagen = ImageDataGenerator(rescale=1./255)
test_datagen = ImageDataGenerator(rescale=1./255)

train_dataset = train_datagen.flow_from_directory(
    train_path,
    target_size=(img_height, img_width),
    batch_size=batch_size,
    class_mode='binary')

test_dataset = test_datagen.flow_from_directory(
    test_path,
    target_size=(img_height, img_width),
    batch_size=batch_size,
    class_mode='binary')

# Load the pretrained VGG16 model
base_model = VGG16(weights='imagenet', include_top=False, input_shape=(img_height, img_width, 3))

# Add custom top layers for binary classification
x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(256, activation='relu')(x)
x = Dropout(0.5)(x)
predictions = Dense(num_classes, activation='sigmoid')(x)

# Create the modified model
model = tf.keras.Model(inputs=base_model.input, outputs=predictions)

# Freeze the layers of the pretrained model
for layer in base_model.layers:
    layer.trainable = False

# Compile the model
model.compile(optimizer=Adam(lr=0.001),
              loss='binary_crossentropy',
              metrics=['accuracy'])

# Train the model
epochs = 100
history = model.fit(
    train_dataset,
    steps_per_epoch=train_dataset.samples // batch_size,
    epochs=epochs,
    validation_data=test_dataset,
    validation_steps=test_dataset.samples // batch_size
)

# Evaluate the model
loss, accuracy = model.evaluate(test_dataset)
print(f"Test Loss: {loss}, Test Accuracy: {accuracy}")

# Save the model
model.save('C:/Users/phd/Downloads/datasets (2)/datasets/balance_dataset/fibroid_detection_VGG16_model.h5')

# Predict classes for test dataset
predictions = model.predict(test_dataset)
predicted_classes = np.where(predictions > 0.5, 1, 0)

# Get true classes
true_classes = test_dataset.classes

# Generate classification report
report = classification_report(true_classes, predicted_classes)

# Print the classification report
print("Classification Report:")
print(report)
# Out:
# C:\Users\phd\AppData\Roaming\Python\Python39\site-packages\pandas\core\computation\expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.8.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# C:\Users\phd\AppData\Roaming\Python\Python39\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (
# Found 1784 images belonging to 2 classes.
# Found 446 images belonging to 2 classes.
# C:\Users\phd\AppData\Roaming\Python\Python39\site-packages\keras\optimizers\optimizer_v2\adam.py:114: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# Epoch 1/100
# 55/55 [==============================] - 313s 6s/step - loss: 0.5676 - accuracy: 0.6992 - val_loss: 0.4584 - val_accuracy: 0.8125
# Epoch 2/100
# 55/55 [==============================] - 307s 6s/step - loss: 0.4785 - accuracy: 0.7677 - val_loss: 0.4322 - val_accuracy: 0.8005
# Epoch 3/100
# 55/55 [==============================] - 344s 6s/step - loss: 0.4541 - accuracy: 0.7848 - val_loss: 0.4285 - val_accuracy: 0.8101
# Epoch 4/100
# 55/55 [==============================] - 354s 6s/step - loss: 0.4193 - accuracy: 0.8116 - val_loss: 0.4101 - val_accuracy: 0.8245
# Epoch 5/100
# 55/55 [==============================] - 280s 5s/step - loss: 0.3967 - accuracy: 0.8259 - val_loss: 0.3687 - val_accuracy: 0.8438
# Epoch 6/100
# 55/55 [==============================] - 236s 4s/step - loss: 0.3910 - accuracy: 0.8116 - val_loss: 0.4237 - val_accuracy: 0.7957
# Epoch 7/100
# 55/55 [==============================] - 236s 4s/step - loss: 0.3534 - accuracy: 0.8453 - val_loss: 0.3548 - val_accuracy: 0.8558
# Epoch 8/100
# 55/55 [==============================] - 238s 4s/step - loss: 0.3529 - accuracy: 0.8373 - val_loss: 0.3614 - val_accuracy: 0.8365
# Epoch 9/100
# 55/55 [==============================] - 237s 4s/step - loss: 0.3395 - accuracy: 0.8453 - val_loss: 0.3568 - val_accuracy: 0.8462
# Epoch 10/100
# 55/55 [==============================] - 238s 4s/step - loss: 0.3436 - accuracy: 0.8413 - val_loss: 0.4086 - val_accuracy: 0.8101
# Epoch 11/100
# 55/55 [==============================] - 237s 4s/step - loss: 0.3204 - accuracy: 0.8602 - val_loss: 0.3704 - val_accuracy: 0.8293
# Epoch 12/100
# 55/55 [==============================] - 236s 4s/step - loss: 0.3159 - accuracy: 0.8630 - val_loss: 0.3413 - val_accuracy: 0.8486
# Epoch 13/100
# 55/55 [==============================] - 236s 4s/step - loss: 0.3087 - accuracy: 0.8630 - val_loss: 0.3363 - val_accuracy: 0.8534
# Epoch 14/100
# 55/55 [==============================] - 236s 4s/step - loss: 0.2978 - accuracy: 0.8744 - val_loss: 0.3274 - val_accuracy: 0.8582
# Epoch 15/100
# 55/55 [==============================] - 236s 4s/step - loss: 0.2886 - accuracy: 0.8773 - val_loss: 0.3092 - val_accuracy: 0.8654
# Epoch 16/100
# 55/55 [==============================] - 237s 4s/step - loss: 0.2929 - accuracy: 0.8767 - val_loss: 0.3226 - val_accuracy: 0.8486
# Epoch 17/100
# 55/55 [==============================] - 237s 4s/step - loss: 0.2752 - accuracy: 0.8841 - val_loss: 0.3598 - val_accuracy: 0.8317
# Epoch 18/100
# 55/55 [==============================] - 237s 4s/step - loss: 0.2802 - accuracy: 0.8790 - val_loss: 0.3252 - val_accuracy: 0.8558
# Epoch 19/100
# 55/55 [==============================] - 236s 4s/step - loss: 0.2624 - accuracy: 0.8927 - val_loss: 0.3317 - val_accuracy: 0.8582
# Epoch 20/100
# 55/55 [==============================] - 236s 4s/step - loss: 0.2776 - accuracy: 0.8836 - val_loss: 0.3213 - val_accuracy: 0.8630
# Epoch 21/100
# 55/55 [==============================] - 236s 4s/step - loss: 0.2576 - accuracy: 0.8950 - val_loss: 0.3032 - val_accuracy: 0.8678
# Epoch 22/100
# 55/55 [==============================] - 236s 4s/step - loss: 0.2529 - accuracy: 0.8961 - val_loss: 0.3416 - val_accuracy: 0.8486
# Epoch 23/100
# 55/55 [==============================] - 215s 4s/step - loss: 0.2472 - accuracy: 0.9018 - val_loss: 0.3319 - val_accuracy: 0.8486
# Epoch 24/100
# 55/55 [==============================] - 130s 2s/step - loss: 0.2539 - accuracy: 0.8990 - val_loss: 0.3532 - val_accuracy: 0.8413
# Epoch 25/100
# 55/55 [==============================] - 130s 2s/step - loss: 0.2492 - accuracy: 0.9018 - val_loss: 0.3083 - val_accuracy: 0.8750
# Epoch 26/100
# 55/55 [==============================] - 132s 2s/step - loss: 0.2447 - accuracy: 0.8984 - val_loss: 0.2979 - val_accuracy: 0.8726
# Epoch 27/100
# 55/55 [==============================] - 131s 2s/step - loss: 0.2487 - accuracy: 0.8990 - val_loss: 0.2846 - val_accuracy: 0.8822
# Epoch 28/100
# 55/55 [==============================] - 131s 2s/step - loss: 0.2302 - accuracy: 0.9058 - val_loss: 0.3536 - val_accuracy: 0.8365
# Epoch 29/100
# 55/55 [==============================] - 131s 2s/step - loss: 0.2296 - accuracy: 0.8973 - val_loss: 0.2927 - val_accuracy: 0.8774
# Epoch 30/100
# 55/55 [==============================] - 131s 2s/step - loss: 0.2276 - accuracy: 0.9064 - val_loss: 0.3182 - val_accuracy: 0.8582
# Epoch 31/100
# 55/55 [==============================] - 131s 2s/step - loss: 0.2225 - accuracy: 0.9110 - val_loss: 0.2837 - val_accuracy: 0.8870
# Epoch 32/100
# 55/55 [==============================] - 130s 2s/step - loss: 0.2070 - accuracy: 0.9212 - val_loss: 0.3094 - val_accuracy: 0.8678
# Epoch 33/100
# 55/55 [==============================] - 130s 2s/step - loss: 0.2116 - accuracy: 0.9115 - val_loss: 0.2953 - val_accuracy: 0.8678
# Epoch 34/100
# 55/55 [==============================] - 130s 2s/step - loss: 0.2120 - accuracy: 0.9184 - val_loss: 0.3085 - val_accuracy: 0.8654
# Epoch 35/100
# 55/55 [==============================] - 130s 2s/step - loss: 0.2032 - accuracy: 0.9229 - val_loss: 0.2847 - val_accuracy: 0.8846
# Epoch 36/100
# 55/55 [==============================] - 130s 2s/step - loss: 0.2047 - accuracy: 0.9138 - val_loss: 0.2913 - val_accuracy: 0.8750
# Epoch 37/100
# 55/55 [==============================] - 131s 2s/step - loss: 0.2072 - accuracy: 0.9218 - val_loss: 0.2867 - val_accuracy: 0.8846
# Epoch 38/100
# 55/55 [==============================] - 131s 2s/step - loss: 0.1978 - accuracy: 0.9258 - val_loss: 0.3191 - val_accuracy: 0.8606
# Epoch 39/100
# 55/55 [==============================] - 131s 2s/step - loss: 0.2130 - accuracy: 0.9110 - val_loss: 0.2747 - val_accuracy: 0.8870
# Epoch 40/100
# 55/55 [==============================] - 131s 2s/step - loss: 0.1956 - accuracy: 0.9224 - val_loss: 0.3035 - val_accuracy: 0.8654
# Epoch 41/100
# 55/55 [==============================] - 131s 2s/step - loss: 0.1881 - accuracy: 0.9309 - val_loss: 0.2739 - val_accuracy: 0.8798
# Epoch 42/100
# 55/55 [==============================] - 130s 2s/step - loss: 0.1800 - accuracy: 0.9361 - val_loss: 0.3010 - val_accuracy: 0.8774
# Epoch 43/100
# 55/55 [==============================] - 131s 2s/step - loss: 0.1895 - accuracy: 0.9252 - val_loss: 0.2546 - val_accuracy: 0.8918
# Epoch 44/100
# 55/55 [==============================] - 130s 2s/step - loss: 0.1836 - accuracy: 0.9298 - val_loss: 0.2987 - val_accuracy: 0.8774
# Epoch 45/100
# 55/55 [==============================] - 131s 2s/step - loss: 0.1865 - accuracy: 0.9304 - val_loss: 0.3501 - val_accuracy: 0.8438
# Epoch 46/100
# 55/55 [==============================] - 131s 2s/step - loss: 0.1822 - accuracy: 0.9235 - val_loss: 0.2920 - val_accuracy: 0.8750
# Epoch 47/100
# 55/55 [==============================] - 130s 2s/step - loss: 0.1684 - accuracy: 0.9355 - val_loss: 0.2929 - val_accuracy: 0.8774
# Epoch 48/100
# 55/55 [==============================] - 131s 2s/step - loss: 0.1667 - accuracy: 0.9386 - val_loss: 0.2902 - val_accuracy: 0.8726
# Epoch 49/100
# 55/55 [==============================] - 130s 2s/step - loss: 0.1643 - accuracy: 0.9338 - val_loss: 0.2701 - val_accuracy: 0.8918
# Epoch 50/100
# 55/55 [==============================] - 130s 2s/step - loss: 0.1659 - accuracy: 0.9326 - val_loss: 0.3074 - val_accuracy: 0.8678
# Epoch 51/100
# 55/55 [==============================] - 130s 2s/step - loss: 0.1571 - accuracy: 0.9355 - val_loss: 0.2825 - val_accuracy: 0.8798
# Epoch 52/100
# 55/55 [==============================] - 131s 2s/step - loss: 0.1536 - accuracy: 0.9435 - val_loss: 0.2775 - val_accuracy: 0.8846
# Epoch 53/100
# 55/55 [==============================] - 131s 2s/step - loss: 0.1557 - accuracy: 0.9452 - val_loss: 0.2770 - val_accuracy: 0.8918
# Epoch 54/100
# 55/55 [==============================] - 130s 2s/step - loss: 0.1584 - accuracy: 0.9372 - val_loss: 0.2879 - val_accuracy: 0.8726
# Epoch 55/100
# 55/55 [==============================] - 130s 2s/step - loss: 0.1565 - accuracy: 0.9366 - val_loss: 0.2903 - val_accuracy: 0.8894
# Epoch 56/100
# 55/55 [==============================] - 130s 2s/step - loss: 0.1530 - accuracy: 0.9420 - val_loss: 0.2700 - val_accuracy: 0.8942
# Epoch 57/100
# 55/55 [==============================] - 130s 2s/step - loss: 0.1517 - accuracy: 0.9435 - val_loss: 0.2787 - val_accuracy: 0.8846
# Epoch 58/100
# 55/55 [==============================] - 130s 2s/step - loss: 0.1479 - accuracy: 0.9429 - val_loss: 0.3430 - val_accuracy: 0.8486
# Epoch 59/100
# 55/55 [==============================] - 130s 2s/step - loss: 0.1399 - accuracy: 0.9463 - val_loss: 0.2797 - val_accuracy: 0.8798
# Epoch 60/100
# 55/55 [==============================] - 129s 2s/step - loss: 0.1399 - accuracy: 0.9486 - val_loss: 0.2789 - val_accuracy: 0.8894
# Epoch 61/100
# 55/55 [==============================] - 130s 2s/step - loss: 0.1408 - accuracy: 0.9475 - val_loss: 0.3180 - val_accuracy: 0.8678
# Epoch 62/100
# 55/55 [==============================] - 129s 2s/step - loss: 0.1410 - accuracy: 0.9503 - val_loss: 0.2795 - val_accuracy: 0.8894
# Epoch 63/100
# 55/55 [==============================] - 129s 2s/step - loss: 0.1366 - accuracy: 0.9498 - val_loss: 0.2742 - val_accuracy: 0.8870
# Epoch 64/100
# 55/55 [==============================] - 129s 2s/step - loss: 0.1271 - accuracy: 0.9589 - val_loss: 0.2841 - val_accuracy: 0.8990
# Epoch 65/100
# 55/55 [==============================] - 129s 2s/step - loss: 0.1202 - accuracy: 0.9543 - val_loss: 0.2723 - val_accuracy: 0.8846
# Epoch 66/100
# 55/55 [==============================] - 129s 2s/step - loss: 0.1448 - accuracy: 0.9378 - val_loss: 0.2839 - val_accuracy: 0.8798
# Epoch 67/100
# 55/55 [==============================] - 129s 2s/step - loss: 0.1290 - accuracy: 0.9515 - val_loss: 0.2579 - val_accuracy: 0.8750
# Epoch 68/100
# 55/55 [==============================] - 129s 2s/step - loss: 0.1227 - accuracy: 0.9566 - val_loss: 0.2555 - val_accuracy: 0.9111
# Epoch 69/100
# 55/55 [==============================] - 129s 2s/step - loss: 0.1243 - accuracy: 0.9543 - val_loss: 0.2754 - val_accuracy: 0.8870
# Epoch 70/100
# 55/55 [==============================] - 129s 2s/step - loss: 0.1153 - accuracy: 0.9532 - val_loss: 0.2722 - val_accuracy: 0.8942
# Epoch 71/100
# 55/55 [==============================] - 129s 2s/step - loss: 0.1282 - accuracy: 0.9492 - val_loss: 0.2741 - val_accuracy: 0.8918
# Epoch 72/100
# 55/55 [==============================] - 129s 2s/step - loss: 0.1244 - accuracy: 0.9509 - val_loss: 0.2738 - val_accuracy: 0.8798
# Epoch 73/100
# 55/55 [==============================] - 128s 2s/step - loss: 0.1182 - accuracy: 0.9566 - val_loss: 0.2785 - val_accuracy: 0.8918
# Epoch 74/100
# 55/55 [==============================] - 129s 2s/step - loss: 0.1198 - accuracy: 0.9572 - val_loss: 0.3085 - val_accuracy: 0.8750
# Epoch 75/100
# 55/55 [==============================] - 129s 2s/step - loss: 0.1168 - accuracy: 0.9543 - val_loss: 0.2755 - val_accuracy: 0.8894
# Epoch 76/100
# 55/55 [==============================] - 128s 2s/step - loss: 0.1204 - accuracy: 0.9526 - val_loss: 0.2771 - val_accuracy: 0.8798
# Epoch 77/100
# 55/55 [==============================] - 128s 2s/step - loss: 0.1143 - accuracy: 0.9555 - val_loss: 0.2990 - val_accuracy: 0.8894
# Epoch 78/100
# 55/55 [==============================] - 128s 2s/step - loss: 0.1018 - accuracy: 0.9612 - val_loss: 0.2712 - val_accuracy: 0.8990
# Epoch 79/100
# 55/55 [==============================] - 128s 2s/step - loss: 0.0970 - accuracy: 0.9640 - val_loss: 0.3028 - val_accuracy: 0.8846
# Epoch 80/100
# 55/55 [==============================] - 127s 2s/step - loss: 0.1069 - accuracy: 0.9612 - val_loss: 0.2646 - val_accuracy: 0.8846
# Epoch 81/100
# 55/55 [==============================] - 129s 2s/step - loss: 0.1011 - accuracy: 0.9640 - val_loss: 0.2716 - val_accuracy: 0.8942
# Epoch 82/100
# 55/55 [==============================] - 128s 2s/step - loss: 0.0981 - accuracy: 0.9669 - val_loss: 0.2812 - val_accuracy: 0.8966
# Epoch 83/100
# 55/55 [==============================] - 127s 2s/step - loss: 0.1046 - accuracy: 0.9629 - val_loss: 0.3149 - val_accuracy: 0.8822
# Epoch 84/100
# 55/55 [==============================] - 128s 2s/step - loss: 0.0914 - accuracy: 0.9749 - val_loss: 0.2835 - val_accuracy: 0.8870
# Epoch 85/100
# 55/55 [==============================] - 128s 2s/step - loss: 0.0890 - accuracy: 0.9697 - val_loss: 0.2715 - val_accuracy: 0.8918
# Epoch 86/100
# 55/55 [==============================] - 129s 2s/step - loss: 0.0926 - accuracy: 0.9699 - val_loss: 0.3225 - val_accuracy: 0.8774
# Epoch 87/100
# 55/55 [==============================] - 127s 2s/step - loss: 0.0899 - accuracy: 0.9709 - val_loss: 0.2957 - val_accuracy: 0.8846
# Epoch 88/100
# 55/55 [==============================] - 128s 2s/step - loss: 0.0802 - accuracy: 0.9755 - val_loss: 0.2775 - val_accuracy: 0.8798
# Epoch 89/100
# 55/55 [==============================] - 128s 2s/step - loss: 0.0818 - accuracy: 0.9749 - val_loss: 0.2772 - val_accuracy: 0.8918
# Epoch 90/100
# 55/55 [==============================] - 129s 2s/step - loss: 0.0805 - accuracy: 0.9737 - val_loss: 0.2812 - val_accuracy: 0.8918
# Epoch 91/100
# 55/55 [==============================] - 128s 2s/step - loss: 0.0849 - accuracy: 0.9697 - val_loss: 0.2856 - val_accuracy: 0.8798
# Epoch 92/100
# 55/55 [==============================] - 127s 2s/step - loss: 0.0814 - accuracy: 0.9703 - val_loss: 0.3087 - val_accuracy: 0.8918
# Epoch 93/100
# 55/55 [==============================] - 128s 2s/step - loss: 0.0894 - accuracy: 0.9675 - val_loss: 0.3180 - val_accuracy: 0.8918
# Epoch 94/100
# 55/55 [==============================] - 128s 2s/step - loss: 0.0766 - accuracy: 0.9732 - val_loss: 0.2912 - val_accuracy: 0.8918
# Epoch 95/100
# 55/55 [==============================] - 128s 2s/step - loss: 0.0839 - accuracy: 0.9720 - val_loss: 0.2898 - val_accuracy: 0.8990
# Epoch 96/100
# 55/55 [==============================] - 127s 2s/step - loss: 0.0688 - accuracy: 0.9760 - val_loss: 0.3072 - val_accuracy: 0.8894
# Epoch 97/100
# 55/55 [==============================] - 127s 2s/step - loss: 0.0715 - accuracy: 0.9806 - val_loss: 0.3285 - val_accuracy: 0.8726
# Epoch 98/100
# 55/55 [==============================] - 128s 2s/step - loss: 0.0737 - accuracy: 0.9743 - val_loss: 0.3066 - val_accuracy: 0.8846
# Epoch 99/100
# 55/55 [==============================] - 127s 2s/step - loss: 0.0780 - accuracy: 0.9755 - val_loss: 0.3797 - val_accuracy: 0.8678
# Epoch 100/100
# 55/55 [==============================] - 127s 2s/step - loss: 0.0757 - accuracy: 0.9755 - val_loss: 0.3185 - val_accuracy: 0.8798
# 14/14 [==============================] - 26s 2s/step - loss: 0.3171 - accuracy: 0.8789
# Test Loss: 0.31709638237953186, Test Accuracy: 0.878923773765564
# 14/14 [==============================] - 26s 2s/step
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.48      0.43      0.46       223
#            1       0.49      0.53      0.51       223
#
#     accuracy                           0.48       446
#    macro avg       0.48      0.48      0.48       446
# weighted avg       0.48      0.48      0.48       446
